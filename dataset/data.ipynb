# %%
import pandas as pd

# %%
book_tags = pd.read_csv('book_tags.csv')
books = pd.read_csv('books.csv')
ratings = pd.read_csv('ratings.csv', )
tags = pd.read_csv('tags.csv')
to_read = pd.read_csv('to_read.csv')

# %%
books

books["isbn13"] = books["isbn13"].apply(
    lambda x: str(int(x)) if pd.notnull(x) else ""
)

books
# Out:
#       book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 0           1            2767052       2767052   2792775          272
# 1           2                  3             3   4640799          491
# 2           3              41865         41865   3212258          226
# 3           4               2657          2657   3275794          487
# 4           5               4671          4671    245494         1356
# ...       ...                ...           ...       ...          ...
# 9995     9996            7130616       7130616   7392860           19
# 9996     9997             208324        208324   1084709           19
# 9997     9998              77431         77431   2393986           60
# 9998     9999            8565083       8565083  13433613            7
# 9999    10000               8914          8914     11817           31
#
#             isbn         isbn13                      authors  \
# 0      439023483  9780439023480              Suzanne Collins
# ...

# %%
print(books.columns)

books = books[["book_id", "isbn13", "isbn", "authors", 
               "original_publication_year", 
               "title", "average_rating", 
               "ratings_1", "ratings_2", 
               "ratings_3", "ratings_4", 
               "ratings_5", "ratings_count"]]

books.to_csv("books_clean.csv", index=False)

books[books["title"] == "Cocktails for Three"]
# Out:
# Index(['book_id', 'isbn13', 'isbn', 'authors', 'original_publication_year',
#        'title', 'average_rating', 'ratings_1', 'ratings_2', 'ratings_3',
#        'ratings_4', 'ratings_5', 'ratings_count'],
#       dtype='object')
#       book_id         isbn13       isbn            authors  \
# 3033     3034  9780312350000  312349998  Madeleine Wickham
#
#       original_publication_year                title  average_rating  \
# 3033                     2000.0  Cocktails for Three            3.38
#
#       ratings_1  ratings_2  ratings_3  ratings_4  ratings_5  ratings_count
# 3033       1356       4451      12253       8856       5349          30415

# %%
ratings
# Out:
#          user_id  book_id  rating
# 0              1      258       5
# 1              2     4081       4
# 2              2      260       5
# 3              2     9296       5
# 4              2     2318       3
# ...          ...      ...     ...
# 5976474    49925      510       5
# 5976475    49925      528       4
# 5976476    49925      722       4
# 5976477    49925      949       5
# 5976478    49925     1023       4
#
# [5976479 rows x 3 columns]

# %%
tags
# Out:
#        tag_id    tag_name
# 0           0           -
# 1           1        --1-
# 2           2       --10-
# 3           3       --12-
# 4           4      --122-
# ...       ...         ...
# 34247   34247   Ｃhildrens
# 34248   34248   Ｆａｖｏｒｉｔｅｓ
# 34249   34249       Ｍａｎｇａ
# 34250   34250      ＳＥＲＩＥＳ
# 34251   34251  ｆａｖｏｕｒｉｔｅｓ
#
# [34252 rows x 2 columns]

# %%
to_read
# Out:
#         user_id  book_id
# 0             9        8
# 1            15      398
# 2            15      275
# 3            37     7173
# 4            34      380
# ...         ...      ...
# 912700    39374     1049
# 912701    10492     5180
# 912702    21879     4827
# 912703    21879     6642
# 912704    48192     7773
#
# [912705 rows x 2 columns]
